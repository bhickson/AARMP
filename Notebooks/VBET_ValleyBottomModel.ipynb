# %%
# VBET VAllEY BOTTOM MODEL
#     The final output of the script is placed in nhd_dir as "VBET_ValleyBottoms.tif"

# %%
if __name__ == '__main__':
    # Import necessary modules
    from shapely.geometry import Point
    from shapely.ops import linemerge
    import rasterio as rio
    import pandas as pd
    import geopandas as gpd
    import gdal, osr
    import numpy as np
    import os, shutil
    import math
    from rasterio.merge import merge as merge_tool
    #import Utilities as utils
    import logging as localLog
    
    
    localLog.basicConfig(level=localLog.INFO)

    overwrite = False
    cleanup = False
    vb_dir = os.path.abspath(r"M:\Data\ValleyBottoms")
    
    #print("Using NHD directory %s" % nhd_dir)
    
    watersheds_dir = os.path.join(vb_dir, "Watersheds")
    
    """Large Slope Threshold: The value that represents the upper limit of slopes that will be included in the valley bottom 
    for the 'large' portions of the network."""
    large_slope_thresh = 2
    """Medium Slope Threshold: The value that represents the upper limit of slopes that will be included in the valley bottom
     for the 'medium' portions of the network."""
    medium_slope_thresh = 5
    """Small Slope Threshold: The value that represents the upper limit of slopes that will be included in the valley bottoms
     for the "small" portions of the network."""
    small_slope_thresh = 22
    
    """High Drainage Area Threshold: The drainage area value in square meters. Streams whose upstream drainage area is greater 
    than this value will be considered the "large" portion of the network, and whose maximum valley bottom width will be 
    represented with the "Large Buffer Size" parameter."""
    high_drainage_area_thresh = 1000000  # (m2)
    """Low Drainage Area Threshold: The drainage area value in square meters. Streams whose upstream drainage area is less 
    than this value will be considered the "small" portion of the network, and whose maximum valley bottom width will be 
    represented with the "Small Buffer Size" parameter. Streams whose upstream drainage area is between the high and low 
    drainage area thresholds will be considered the "medium" portion of the network and their maximum valley bottom width 
    represented by the "Medium Buffer Width" parameter."""
    low_drainage_area_thresh = 40000     # (m2)
    
    #createVBETValleyBottom(vb_dir, watersheds_dir, large_slope_thresh, medium_slope_thresh, small_slope_thresh,
    #                       overwrite=True, cleanup=False)

# %%
#def createVBETValleyBottom(indir, watershedsDir, lrgSlopeThresh, medSlopeThresh,
#                           smSlopeThresh, overwrite=False, cleanup=False):
""" Creates a single output valley bottom using the VBET methodology. First iterates watersheds directory 
for each HUC4 watersheds and """
indir=vb_dir
watershedsDir=watersheds_dir
lrgSlopeThresh=large_slope_thresh
medSlopeThresh=medium_slope_thresh
smSlopeThresh=small_slope_thresh

# The final output of the script
vbet_allwatersheds = os.path.join(indir, "VBET_ValleyBottoms.tif")

# Watershed Size Column Name
watershed_col = "TotDASqKm"

if not os.path.exists(vbet_allwatersheds) or overwrite or True:
    localLog.info("\nValley Bottom Raster based on VBET methodology doesn't exist. Beginning creation.\n")
    # Final output file doesn't exist, begin creation

    flow_acc_thresh = 2000  # minimum flow accumulation size to identify stream
    #ValleyBottomRastersPrep.vb_prep(watershedsDir, flow_initiation_threshold=flow_acc_thresh)

    # Need to divide by 1000 because of the PercentRise calculation used in Esri's Slope Determination. Just a component of predictor variables.
    lrgSlopeThresh = lrgSlopeThresh/1000
    medSlopeThresh = medSlopeThresh/1000
    smSlopeThresh = smSlopeThresh/1000

    print(watershedsDir)

    for w_dir in os.listdir(watershedsDir):
        localLog.info("--- BEGINNING ON WATERSHED %s ---" % w_dir)
        watershed_dir = os.path.join(watershedsDir, w_dir)
        for subdir in os.listdir(watershed_dir):
            if "Rasters" in subdir:
                rasters_dir = os.path.join(watershed_dir, subdir)
            if "GDB" in subdir:
                geodatabase = os.path.join(watershed_dir, subdir)

        fac_raster_loc = os.path.join(rasters_dir, "fac.tif")
        preds_dir = os.path.join(rasters_dir, "Predictors")
        intermediate_preds_dir = os.path.join(rasters_dir, "RSAC_Intermediates")
        dem_ras = os.path.join(preds_dir, "elev_meters.tif")
        slope_ras = os.path.join(intermediate_preds_dir, "Slope.tif")

        if not os.path.exists(slope_ras) or not os.path.exists(dem_ras):
            localLog.error("Slope raster does not exist. Run RSAC preprocessing script from ArcGIS python environment.")
            raise Exception

        flowlines_vector = os.path.join(watershed_dir, "NHD_Flowlines_buffered.gpkg")
        flowlines_raster = os.path.join(watershed_dir, "NHD_Flowlines_buffered.tif")
        flowlines_clipped_raster = os.path.join(watershed_dir, "NHD_Flowlines_buffered_clipped.tif")

        if not os.path.exists(flowlines_clipped_raster) or not os.path.exists(flowlines_raster) or overwrite:
            localLog.info("%s doesn't exist. Beginning creation..." % flowlines_clipped_raster)

            localLog.debug("Reading in NHD flowlines feature class from geodatabase...")
            flowlines = gpd.GeoDataFrame.from_file(geodatabase, layer='NHDFlowline')

            raster_crs = getRasterProj4(fac_raster_loc)
            localLog.debug("Reprojecting flowlines dataframe to FAC raster projection...")
            flowlines.to_crs(raster_crs, inplace=True)

            # GET VAA TABLE AND JOIN TO FEATURE CLASS FOR WATERSHED SIZE
            flowlines_vaa = gpd.GeoDataFrame.from_file(geodatabase, layer='NHDPlusFlowlineVAA')

            flowlines = flowlines.merge(flowlines_vaa, on='NHDPlusID')
            
            flowlines = gpd.GeoDataFrame(flowlines)

            # Merge renames geometry to geometry_x. Fix
            flowlines['geometry'] = flowlines['geometry_x']

            # Cleanup flowlines table by removing all columns not geometry
            drop_columns = flowlines.columns.tolist()
            drop_columns.remove('geometry')
            drop_columns.remove(watershed_col)

            # TODO - select only flowlines which are true in-ground streams. Do not include canals, culverts, etc
            #pipline underground  - FCODE 42803, 42804, 42807, 42808, 42812...

            flowlines.drop(drop_columns, axis=1, inplace=True)

            # Create new column 'fac_poly' (Flow accumulation poly) and calculate the single point geometry 
            #     of the vertex. This is used to extract the flow accumulation value of the line string. 
            localLog.debug("Finding node on flowline and buffering...")

            # get resolution
            with rio.open(fac_raster_loc) as ras:
                res_x, res_y = ras.res

            #pixel X number in km
            ratio_x = 1000 / res_x
            ratio_y = 1000 / res_y

            flowlines["TotDASq_m"] = flowlines[watershed_col] * ratio_x * ratio_y

            def calculateBufferSize(da):
                if da <= 1:
                    buff_size = 1
                else:
                    buff_size = math.sqrt(da) / (math.log(da, 10) * (4 / 3))

                return buff_size

            def bufferLines(row):
                geom = row.geometry
                buffersize = row.BufferSize
                #fac = row[watershed_col]

                # log of 1 is 0, can't divide by zero. Also, a Flow accumulation value of 1 or zero is a misread, essentially minimum buffer size
                #if fac <= 1:
                #    fac = 2

                """Simple equation which correlates the flow accumulation values (fac), e.g. watershed size,
                to the appropriate valley bottom buffer"""
                #buffersize = math.sqrt(fac) / (math.log(fac, 10) * (4 / 3))

                return geom.buffer(buffersize)


            flowlines["BufferSize"] = flowlines["TotDASq_m"].apply(calculateBufferSize)

            # Buffer each flowline by its watershed size
            flowlines["geometry"] = flowlines.apply(bufferLines, axis=1)

            # Drop the now unused fac_poly column. Cleaner and can't write to file with two geometry columns
            #flowlines.drop(["fac_poly"], axis=1, inplace=True)
            # Write out to shapefile
            localLog.debug("Writing out flowline buffers to file: %s" % flowlines_vector)
            print("Flowline dtypes:\n {}".format(flowlines.dtypes))
    
            flowlines.to_file(flowlines_vector)

            # Rasterize buffered flowlines
            outbuffer_ras = os.path.join(preds_dir, "WatershedBufferSize")
            if not os.path.exists(outbuffer_ras) or overwrite:
                print("Rasterizing %s ..." % flowlines_vector)
                rasterinfo = getResAndExtent(dem_ras) # use dem_ras just for sample
                extent = " ".join(rasterinfo[2:])
                res_x = str(rasterinfo[0])
                res_y = str(rasterinfo[1])
                opts = "-a BufferSize" + " -a_nodata -9999 -tr " + res_x + " " + res_y + " -te " + extent
                # print(opts)
                gdal.Rasterize(outbuffer_ras, flowlines_vector, options=opts)
# Out:
# INFO:root:
# Valley Bottom Raster based on VBET methodology doesn't exist. Beginning creation.
#
# INFO:root:--- BEGINNING ON WATERSHED 1407 ---
# INFO:root:--- BEGINNING ON WATERSHED 1408 ---
# INFO:root:M:\Data\ValleyBottoms\Watersheds\1408\NHD_Flowlines_buffered_clipped.tif doesn't exist. Beginning creation...
# WARNING:Fiona:PROJ data files not located, PROJ_LIB not set
# M:\Data\ValleyBottoms\Watersheds
# WARNING:Fiona:PROJ data files not located, PROJ_LIB not set
# Flowline dtypes:
#  TotDASqKm     float64
# geometry       object
# TotDASq_m     float64
# BufferSize    float64
# dtype: object
# WARNING:Fiona:PROJ data files not located, PROJ_LIB not set
# WARNING:Fiona:PROJ data files not located, PROJ_LIB not set
# WARNING:Fiona:CPLE_AppDefined in b'Value 553428202.912800074 of field TotDASq_m of feature 43 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 576302100.914399981 of field TotDASq_m of feature 96 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 549218395.912500024 of field TotDASq_m of feature 394 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 553470185.912599921 of field TotDASq_m of feature 542 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 553117486.912500024 of field TotDASq_m of feature 700 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 552068669.913100004 of field TotDASq_m of feature 816 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 552085385.912699938 of field TotDASq_m of feature 817 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 446423488.913800001 of field TotDASq_m of feature 3513 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 124321483.976899996 of field TotDASq_m of feature 3609 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 124155160.976700023 of field TotDASq_m of feature 3610 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 435933642.913500011 of field TotDASq_m of feature 3644 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 430750064.916999996 of field TotDASq_m of feature 3645 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 430152443.917199969 of field TotDASq_m of feature 3696 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 430152141.917300045 of field TotDASq_m of feature 3698 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 446437536.914000034 of field TotDASq_m of feature 3826 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 446405535.914000034 of field TotDASq_m of feature 3827 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 147066180.970899999 of field TotDASq_m of feature 3858 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 147068268.971399993 of field TotDASq_m of feature 3859 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 341649496.923500001 of field TotDASq_m of feature 4018 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 341688783.922899961 of field TotDASq_m of feature 4019 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 107848615.9912 of field TotDASq_m of feature 4564 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 202854600.937700003 of field TotDASq_m of feature 4598 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 202845327.93779999 of field TotDASq_m of feature 4599 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 138938721.972799987 of field TotDASq_m of feature 4622 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 109004322.990100011 of field TotDASq_m of feature 5324 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 109369508.989600003 of field TotDASq_m of feature 5326 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 109040885.990299985 of field TotDASq_m of feature 5327 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 109106747.9903 of field TotDASq_m of feature 5328 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 446198770.914099991 of field TotDASq_m of feature 7175 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 430114681.917299986 of field TotDASq_m of feature 7558 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 430113647.917699993 of field TotDASq_m of feature 7559 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 430045689.917699993 of field TotDASq_m of feature 7560 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 430042309.917699993 of field TotDASq_m of feature 7561 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 341240194.923200011 of field TotDASq_m of feature 7639 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 341597972.923500001 of field TotDASq_m of feature 7640 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 199978395.937099993 of field TotDASq_m of feature 7645 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 199929325.936800003 of field TotDASq_m of feature 7646 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 110242258.989600003 of field TotDASq_m of feature 7689 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 110130118.989999995 of field TotDASq_m of feature 7703 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 201746271.937599987 of field TotDASq_m of feature 8176 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 201572334.937299997 of field TotDASq_m of feature 8178 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 202208717.9375 of field TotDASq_m of feature 8180 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 430039196.917800069 of field TotDASq_m of feature 8240 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 429136127.916999996 of field TotDASq_m of feature 8241 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 430038918.917699993 of field TotDASq_m of feature 8242 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 430038908.917600036 of field TotDASq_m of feature 8243 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 586300142.914600015 of field TotDASq_m of feature 8752 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 429133287.917200029 of field TotDASq_m of feature 8759 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 428606292.916699946 of field TotDASq_m of feature 9002 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 426616291.916100025 of field TotDASq_m of feature 9003 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 430184513.917800069 of field TotDASq_m of feature 9396 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 586551932.914900064 of field TotDASq_m of feature 10102 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 435667265.913500011 of field TotDASq_m of feature 10106 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 430171015.917600036 of field TotDASq_m of feature 10108 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 430155442.917499959 of field TotDASq_m of feature 10109 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 430047907.917699933 of field TotDASq_m of feature 10160 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 430042330.917699993 of field TotDASq_m of feature 10161 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 429136239.916999996 of field TotDASq_m of feature 10162 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 429135988.917000055 of field TotDASq_m of feature 10163 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 430037915.917699993 of field TotDASq_m of feature 10164 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 430020920.917800069 of field TotDASq_m of feature 10165 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 572626622.913500071 of field TotDASq_m of feature 10194 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 548186532.91230011 of field TotDASq_m of feature 10253 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 539121804.912500024 of field TotDASq_m of feature 10257 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 325117536.925000012 of field TotDASq_m of feature 10492 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 447949589.914800048 of field TotDASq_m of feature 10512 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 325108603.925400019 of field TotDASq_m of feature 11154 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 447922126.914600015 of field TotDASq_m of feature 11305 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 447907973.914199948 of field TotDASq_m of feature 11306 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 202328157.937900007 of field TotDASq_m of feature 15680 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 201410528.9375 of field TotDASq_m of feature 15681 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 202240206.93779999 of field TotDASq_m of feature 15727 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 362494735.926599979 of field TotDASq_m of feature 15769 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 136083853.974299997 of field TotDASq_m of feature 15917 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 136083767.97420001 of field TotDASq_m of feature 15918 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 136069904.974000007 of field TotDASq_m of feature 15919 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 362046194.92689997 of field TotDASq_m of feature 16521 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 147041883.971500009 of field TotDASq_m of feature 16535 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 201490500.937600017 of field TotDASq_m of feature 16615 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 201484848.937599987 of field TotDASq_m of feature 16616 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 446209016.914099991 of field TotDASq_m of feature 16866 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 446103993.914099991 of field TotDASq_m of feature 16868 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 201380231.937700003 of field TotDASq_m of feature 17076 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 201522546.937299997 of field TotDASq_m of feature 17077 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 201508376.937399983 of field TotDASq_m of feature 17078 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 201491189.937700003 of field TotDASq_m of feature 17079 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 201491097.937599987 of field TotDASq_m of feature 17080 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 362187771.926400006 of field TotDASq_m of feature 17154 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 146913987.970800012 of field TotDASq_m of feature 17251 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 393609921.921900034 of field TotDASq_m of feature 119209 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 339420833.923099995 of field TotDASq_m of feature 119265 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 461411933.914900005 of field TotDASq_m of feature 119408 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 461411724.914899945 of field TotDASq_m of feature 119409 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 453979560.914999962 of field TotDASq_m of feature 119412 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 375391005.924099982 of field TotDASq_m of feature 119470 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 375407959.924399972 of field TotDASq_m of feature 119471 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 375403317.924400032 of field TotDASq_m of feature 119472 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 375384119.924300015 of field TotDASq_m of feature 119473 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 375641931.924399972 of field TotDASq_m of feature 119474 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 375617711.924300015 of field TotDASq_m of feature 119477 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 146913862.970800012 of field TotDASq_m of feature 119671 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 138938730.972800016 of field TotDASq_m of feature 119850 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 138938455.972800016 of field TotDASq_m of feature 119851 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 138938915.9727 of field TotDASq_m of feature 119852 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 138690098.97299999 of field TotDASq_m of feature 119853 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 138926302.972800016 of field TotDASq_m of feature 119854 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 329286105.92719996 of field TotDASq_m of feature 120018 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 325263452.925300002 of field TotDASq_m of feature 120019 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 105091758.990400001 of field TotDASq_m of feature 120152 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 105110680.990099996 of field TotDASq_m of feature 120153 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 105128840.990100011 of field TotDASq_m of feature 120154 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 105112729.990199998 of field TotDASq_m of feature 120155 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 587701414.913699985 of field TotDASq_m of feature 120480 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 447924139.914700031 of field TotDASq_m of feature 120738 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 446467762.914200008 of field TotDASq_m of feature 120739 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 446466459.914099991 of field TotDASq_m of feature 120741 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 375154562.924499989 of field TotDASq_m of feature 120759 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 375150565.924499989 of field TotDASq_m of feature 120760 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 375129694.924400032 of field TotDASq_m of feature 120761 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 105578714.989700004 of field TotDASq_m of feature 120887 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 105740539.989600003 of field TotDASq_m of feature 120888 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 105632615.989700004 of field TotDASq_m of feature 120889 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 105631271.989800006 of field TotDASq_m of feature 120890 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 105630675.989799991 of field TotDASq_m of feature 120891 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 105744396.989800006 of field TotDASq_m of feature 120892 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 105744568.989799991 of field TotDASq_m of feature 120893 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 105750803.989600018 of field TotDASq_m of feature 120894 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 105744739.989800006 of field TotDASq_m of feature 120895 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 107555035.991299987 of field TotDASq_m of feature 120896 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 201351744.93719998 of field TotDASq_m of feature 120993 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 201359226.937599987 of field TotDASq_m of feature 120995 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 200012578.937299997 of field TotDASq_m of feature 120996 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 548495599.912999988 of field TotDASq_m of feature 121166 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 136188936.973800004 of field TotDASq_m of feature 121316 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 136188916.973800004 of field TotDASq_m of feature 121317 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 446209214.914100051 of field TotDASq_m of feature 121372 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 375129592.924300015 of field TotDASq_m of feature 121463 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 367790504.926299989 of field TotDASq_m of feature 121620 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 558157309.911999941 of field TotDASq_m of feature 121636 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 553474668.912799954 of field TotDASq_m of feature 121637 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 550889881.913499951 of field TotDASq_m of feature 121640 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 551106965.912700057 of field TotDASq_m of feature 121641 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 138628074.97359997 of field TotDASq_m of feature 121726 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 436661445.913300037 of field TotDASq_m of feature 122146 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 367043096.927699983 of field TotDASq_m of feature 122228 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 366839717.927699983 of field TotDASq_m of feature 122229 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 366839606.927700043 of field TotDASq_m of feature 122230 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 366848776.92809999 of field TotDASq_m of feature 122231 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 367790549.926199973 of field TotDASq_m of feature 122234 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 202266582.93780002 of field TotDASq_m of feature 122316 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 202312697.937700003 of field TotDASq_m of feature 122317 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 202305009.937700033 of field TotDASq_m of feature 122318 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 374691554.924700022 of field TotDASq_m of feature 122642 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 371964265.925499976 of field TotDASq_m of feature 122643 not successfully written. Possibly due to too larger number with respect to field width'
# WARNING:Fiona:CPLE_AppDefined in b'Value 446104637.914399981 of field TotDASq_m of feature 122671 not successfully written. Possibly due to too larger number with respect to field width'

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
def getRasterProj4(raster):
    """ Function returns the projection of the input raster in proj4"""
    fac = gdal.Open(raster)

    ras_proj = fac.GetProjection()
    spatialRef = osr.SpatialReference()

    osr.UseExceptions()
    # Apparently osr has difficulties identifying albers projections
    prjText = ras_proj.replace('"Albers"', '"Albers_Conic_Equal_Area"')
    spatialRef.ImportFromWkt(prjText)
    ras_proj_proj4 = spatialRef.ExportToProj4()
    return ras_proj_proj4

def getRasterTransform(rasterLoc):
    with rio.open(rasterLoc) as raster:
        t = raster.affine
        
    return t


def calculateGeom(row):
    """ Is passed a row containing flowline geometry. Finds the node
    in the geometry which is closest to center and then creates and 
    returns a 5m buffered polygon"""
    geom = row["geometry"]
    if geom.geom_type == "MultiLineString":
        geom = linemerge(geom)
    num_nodes = len(geom.coords)
    if not num_nodes == 2:
        # IF LINESTRING IS NOT COMPOSED OF ONLY TWO NODES, GET THE NODE IN THE MIDDLE MOST OF THE LINE
        point = Point(geom.coords[int(num_nodes/2)])
        bufferSize = 10
    else:
        #print("Two point linestring...")
        # IF TWO POINT LINESTRING, SMALL STREAM ANYWAY. TAKE THE POINT WHICH IS AT THE END OF THE LINE
        point = Point(geom.coords[-1])
        bufferSize = 5
    
    poly = point.buffer(bufferSize)
        
    #points = createPoints(poly, fac_raster_loc)
    
    return poly


def getSnappedPixelLocation(geom_x, geom_y, ras_aff):
    #print("GEOM_X: ", geom_x, "GEOM_Y: ", geom_y)
    """ Returns set of upper-right snapped pixel locations in set as (x, y)"""
    pix_xsize = ras_aff.a
    pix_ysize = ras_aff.e
    #print(pix_xsize, pix_ysize)

    # get pixel coordinates of the geometry's bounding box
    xvals = sorted([geom_x, ras_aff.c])
    yvals = sorted([geom_y, ras_aff.f])
    #print("XVALS: ", xvals)

    diffx = xvals[1] - xvals[0]
    diffy = yvals[1] - yvals[0]
    #print("DIFFS: ", diffx, diffy)

    pixel_xdiff = float("{0:.11f}".format( diffx % pix_xsize ))  # get modulo pixel difference to float precision of 11 decimals
    pixel_ydiff = float("{0:.11f}".format( diffy % pix_ysize ))  # get modulo pixel difference to float precision of 11 decimals
    #print("PIXEL DIFF: ", pixel_xdiff, pixel_ydiff)

    #snapped pixel locations
    if pixel_xdiff > pix_xsize / 2:
        snapped_ulx = geom_x + (pix_xsize - pixel_xdiff)
    else:
        snapped_ulx = geom_x - pixel_xdiff
   
    if abs(pixel_ydiff) > abs(pix_ysize / 2):
        snapped_uly = geom_y + (abs(pix_ysize) + pixel_ydiff)
    else:
        snapped_uly = geom_y - abs(pixel_ydiff)
            
    if snapped_ulx % pix_xsize != ras_aff.c % pix_xsize:
        print(snapped_ulx % pix_xsize)
        raise ValueError("BAD PIXEL VALUE FOR ULX - ", snapped_ulx)
    if snapped_uly % pix_ysize != ras_aff.f % pix_ysize:
        print(snapped_uly % pix_ysize)
        raise ValueError("BAD PIXEL VALUE FOR ULY - ", snapped_uly)
    
    return {"x": snapped_ulx, "y": snapped_uly}


def createPoints(row):
    #print("CREATE POINTS: ", row)
    global rowcount
    rowcount += 1
    if rowcount % 10000 == 0:
        print("Feature #: ", rowcount)
    
    geom_b = row["fac_poly"].bounds

    ul = getSnappedPixelLocation(geom_b[0], geom_b[3], rt)
    lr = getSnappedPixelLocation(geom_b[2], geom_b[1], rt)

    outshape_x = int(abs(lr["x"] - ul["x"]))
    outshape_y = int(abs(ul["y"] - lr["y"]))
    outshapex_inPixels = int(outshape_x/abs(rt.a))
    outshapey_inPixels = int(outshape_y/abs(rt.e))
    
    if outshapex_inPixels == 0 or outshape_y == 0:
        raise ValueError("Snapped bounding box is not correct", 
                         outshapex_inPixels, outshapey_inPixels)
    
    half_x_size = abs(rt.a)/2
    half_y_size = abs(rt.e)/2
    
    polygon_internal_points = []
    polygon_external_points = []
    
    for x in range(outshapex_inPixels):
        pointx = (ul["x"] + half_x_size) + (x * abs(rt.a))
        for y in range(outshapey_inPixels):
            pointy = (ul["y"] - half_y_size) - (y * abs(rt.e))
            point = Point(pointx, pointy)
            
            if point.within(row["fac_poly"]): # IF WITHIN THE BUFFERED POINT
                #print("POINT: ", point)
                #props = {'Type': str(feature["properties"]["Type"]),
                #         'Class': int(feature["properties"]['Class'])}
                #count += 1
                polygon_internal_points.append(point)
                #pointput.write({'geometry': mapping(point), 'properties': props}
            else:
                polygon_external_points.append(point)
                
    if len(polygon_internal_points) != 0:
        return getMaxRasterValues(polygon_internal_points)
    else:
        # IF NONE ARE IN THE BUFFERED AREA, RETURN ALL OF THEM
        #print("NUMBER OF INTERSECTING POINTS IS 0: ", len(polygon_internal_points))
        return getMaxRasterValues(polygon_external_points)
        #print("NUMBER OF POINTS: ", len(polygon_internal_points))
        #raise ValueError("PROBLEM at feature ", row)
    
def getMaxRasterValues(points):
    """ GET LIST OF POINTS AND CALCULATES THE MAXIMUM VALUES OF ALL THE POINST OF THE fac_raster"""
    values = []
    for point in points:
        for val in fac_raster.sample([(point.x, point.y)]):
            values.append(val[0])
        
    return max(values)

def getResAndExtent(raster_file):
    """ RETURN THE RESOLUTION AND EXTENT OF THE RASTER AS A LIST [resx, resy, xmin, ymin, xmax, ymax]"""
    with rio.open(raster_file) as ras:
        ymax = ras.profile['transform'][5]
        xmin = ras.profile['transform'][2]
        height = ras.profile['height']
        width = ras.profile['width']
        resx = ras.profile['transform'][0]
        resy = ras.profile['transform'][4]
        ymin = ymax + (height * resy)
        xmax = xmin + (width * resx)

        return [abs(resx), abs(resy), str(xmin), str(ymin), str(xmax), str(ymax)]
    
def bufferLines(row):
    geom = row.geometry
    fac = row[watershed_col]
    
    # log of 1 is 0, can't divide by zero. Also, a Flow accumulation value of 1 or zero is a misread, essentially minimum buffer size
    if fac <= 1:
        fac = 2

    """Simple equation which correlates the flow accumulation values (fac), e.g. watershed size,
    to the appropriate valley bottom buffer"""
    buffersize = math.sqrt(fac)/(math.log(fac, 10) * (4/3))
    
    return geom.buffer(buffersize)

# %%
geodatabase = r"M:\Data\ValleyBottoms\Watersheds\1507\NHDPlus_H_1507_GDB.gdb"
flowlines_vaa = gpd.GeoDataFrame.from_file(geodatabase, layer='NHDPlusFlowlineVAA')
flowlines = gpd.GeoDataFrame.from_file(geodatabase, layer='NHDFlowline')

# %%
print(flowlines.shape)
# Out:
# (99931, 19)

# %%
flowlines.columns
# Out:
# Index(['Permanent_Identifier', 'FDate', 'Resolution', 'GNIS_ID', 'GNIS_Name',
#        'LengthKM', 'ReachCode', 'FlowDir', 'WBArea_Permanent_Identifier',
#        'FType', 'FCode', 'MainPath', 'InNetwork', 'VisibilityFilter',
#        'Shape_Length', 'NHDPlusID', 'VPUID', 'Enabled', 'geometry'],
#       dtype='object')

# %%
flowlines = flowlines.merge(flowlines_vaa, on='NHDPlusID')

# Merge renames geometry to geometry_x. Fix
flowlines['geometry'] = flowlines['geometry_x']
#lowlines[watershed_col]
# Out:
# 0          0.4726
# 1        381.7279
# 2          2.1035
# 3         46.5598
# 4         46.1306
# 5         29.1945
# 6          0.2047
# 7          1.3311
# 8         15.5205
# 9          0.2725
# 10         1.5225
# 11         0.9207
# 12         0.7097
# 13         0.0599
# 14         6.4099
# 15         6.4071
# 16         0.2157
# 17         6.8697
# 18         2.8771
# 19         1.2221
# 20       287.7668
# 21       288.6652
# 22       330.3382
# 23       330.2896
# 24       714.9244
# 25       714.8087
# 26       713.9927
# 27         0.6057
# 28         3.1418
# 29         1.3604
#            ...
# 99195      0.0965
# 99196      1.2070
# 99197      7.1543
# 99198      1.1220
# 99199      0.3036
# 99200      1.6421
# 99201      0.1202
# 99202     12.0433
# 99203      0.0440
# 99204      0.1002
# 99205      0.9197
# 99206     17.5111
# 99207      0.1872
# 99208      9.8484
# 99209      0.1131
# 99210     26.1589
# 99211      0.0029
# 99212      0.9897
# 99213     43.4165
# 99214    475.5548
# 99215      4.6044
# 99216      1.9121
# 99217      0.2051
# 99218     10.0342
# 99219      4.2861
# 99220      0.4250
# 99221      0.3396
# 99222      0.5206
# 99223      0.5557
# 99224      0.0331
# Name: TotDASqKm, dtype: float64

# %%
all_columns = flowlines.columns.tolist()
#print(flowlines['geometry_x'].head())
#print(flowlines['geometry'].head())
print(all_columns)
# Out:
# ['Permanent_Identifier', 'FDate', 'Resolution', 'GNIS_ID', 'GNIS_Name', 'LengthKM', 'ReachCode_x', 'FlowDir', 'WBArea_Permanent_Identifier', 'FType', 'FCode', 'MainPath', 'InNetwork', 'VisibilityFilter', 'Shape_Length', 'NHDPlusID', 'VPUID_x', 'Enabled', 'geometry_x', 'StreamLeve', 'StreamOrde', 'StreamCalc', 'FromNode', 'ToNode', 'HydroSeq', 'LevelPathI', 'PathLength', 'TerminalPa', 'ArbolateSu', 'Divergence', 'StartFlag', 'TerminalFl', 'UpLevelPat', 'UpHydroSeq', 'DnLevel', 'DnLevelPat', 'DnHydroSeq', 'DnMinorHyd', 'DnDrainCou', 'FromMeas', 'ToMeas', 'ReachCode_y', 'RtnDiv', 'Thinner', 'VPUIn', 'VPUOut', 'AreaSqKm', 'TotDASqKm', 'DivDASqKm', 'MaxElevRaw', 'MinElevRaw', 'MaxElevSmo', 'MinElevSmo', 'Slope', 'SlopeLenKm', 'ElevFixed', 'HWType', 'HWNodeSqKm', 'StatusFlag', 'VPUID_y', 'geometry_y', 'geometry']

# %%
all_columns = flowlines.columns.tolist()
all_columns.remove('geometry')
all_columns.remove(watershed_col)
                
# TODO - select only flowlines which are true in-ground streams. Do not include canals, culverts, etc

flowlines.drop(all_columns, axis=1, inplace=True)

# %%
flowlines.head()
# Out:
#    TotDASqKm                                           geometry
# 0     0.4726  (LINESTRING Z (-113.2393364680036 34.078086813...
# 1   381.7279  (LINESTRING Z (-113.2066020680543 32.541226682...
# 2     2.1035  (LINESTRING Z (-113.2053928680562 32.816411282...
# 3    46.5598  (LINESTRING Z (-113.2153698013741 32.954081082...
# 4    46.1306  (LINESTRING Z (-113.2150438013746 32.953932682...

# %%
res_x = 10
res_y = 10

ratio_x = 1000 / res_x
ratio_y = 1000 / res_y

flowlines["TotDASq_m"] = flowlines[watershed_col] * ratio_x * ratio_y

# %%
flowlines.head()
# Out:
#    TotDASqKm                                           geometry     TotDASq_m
# 0     0.4726  (LINESTRING Z (-113.2393364680036 34.078086813...  4.726000e+03
# 1   381.7279  (LINESTRING Z (-113.2066020680543 32.541226682...  3.817279e+06
# 2     2.1035  (LINESTRING Z (-113.2053928680562 32.816411282...  2.103500e+04
# 3    46.5598  (LINESTRING Z (-113.2153698013741 32.954081082...  4.655980e+05
# 4    46.1306  (LINESTRING Z (-113.2150438013746 32.953932682...  4.613060e+05

# %%
def calculateBufferSize(da):
    if da <= 1:
        buff_size = 1
    else:
        buff_size = math.sqrt(da) / (math.log(da, 10) * (4 / 3))
    
    return buff_size

# %%
flowlines["BufferSize"] = flowlines["TotDASq_m"].apply(calculateBuffer)#, axis=1)

# %%
flowlines.head()
# Out:
#    TotDASqKm                                           geometry     TotDASq_m  \
# 0     0.4726  (LINESTRING Z (-113.2393364680036 34.078086813...  4.726000e+03
# 1   381.7279  (LINESTRING Z (-113.2066020680543 32.541226682...  3.817279e+06
# 2     2.1035  (LINESTRING Z (-113.2053928680562 32.816411282...  2.103500e+04
# 3    46.5598  (LINESTRING Z (-113.2153698013741 32.954081082...  4.655980e+05
# 4    46.1306  (LINESTRING Z (-113.2150438013746 32.953932682...  4.613060e+05
#
#    BufferSize
# 0   14.031710
# 1  222.636607
# 2   25.162458
# 3   90.289266
# 4   89.935966

# %%
da =  381.7279 * 100 * 100
# Out:
# 222.6366073124281
