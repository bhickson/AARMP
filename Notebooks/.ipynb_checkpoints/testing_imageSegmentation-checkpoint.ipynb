# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage as ndi
import rasterio as rio
import os

from skimage.filters import sobel, scharr, prewitt

# %%
test_image = os.path.abspath(r"Q:\Arid Riparian Project\Data\NAIP_2015_Compressed\m_3211042_nw_12_1_20150530.tif")
training_polygons =

# %%
from skimage import data, io, segmentation, color
from skimage.future import graph
import numpy as np
import rasterio as rio


def _weight_mean_color(graph, src, dst, n):
    """Callback to handle merging nodes by recomputing mean color.

    The method expects that the mean color of `dst` is already computed.

    Parameters
    ----------
    graph : RAG
        The graph under consideration.
    src, dst : int
        The vertices in `graph` to be merged.
    n : int
        A neighbor of `src` or `dst` or both.

    Returns
    -------
    data : dict
        A dictionary with the `"weight"` attribute set as the absolute
        difference of the mean color between node `dst` and `n`.
    """

    diff = graph.node[dst]['mean color'] - graph.node[n]['mean color']
    diff = np.linalg.norm(diff)
    return {'weight': diff}


def merge_mean_color(graph, src, dst):
    """Callback called before merging two nodes of a mean color distance graph.

    This method computes the mean color of `dst`.

    Parameters
    ----------
    graph : RAG
        The graph under consideration.
    src, dst : int
        The vertices in `graph` to be merged.
    """
    graph.node[dst]['total color'] += graph.node[src]['total color']
    graph.node[dst]['pixel count'] += graph.node[src]['pixel count']
    graph.node[dst]['mean color'] = (graph.node[dst]['total color'] /
                                     graph.node[dst]['pixel count'])


nir_image = r"Q:/Arid Riparian Project/Data/test/test_NAIP_sub1.tif"
with rio.open(nir_image) as nir_im:
    nir_array = nir_im.read(1).astype(float)

    io.imshow(nir_array)
    io.show()

labels = segmentation.slic(nir_array, compactness=10, n_segments=3000)
g = graph.rag_mean_color(nir_array, labels)

labels2 = graph.merge_hierarchical(labels, g, thresh=20, rag_copy=False,
                                   in_place_merge=True,
                                   merge_func=merge_mean_color,
                                   weight_func=_weight_mean_color)

out = color.label2rgb(labels2, nir_array, kind='avg')
io.imshow(out)
io.show()

# %% [markdown]
# ## CANNY EDGE DETECTION

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage as ndi
from skimage import io

import matplotlib.image as mpimg
import os
import rasterio as rio


from skimage import feature
    
s_val = 2

outdir = r"Q:\Arid Riparian Project\Data\test"

image = r"Q:/Arid Riparian Project/Data/NAIP_2015_Compressed/m_3311248_ne_12_1_20150529.tif"
#with rio.open(image) as im:
#    full_array = im.read().astype(float)

#nir_image = r"Q:/Arid Riparian Project/Data/test/test_NAIP_sub4.tif"
with rio.open(image) as nir_im:
    kwargs = nir_im.profile
    kwargs.update(count=1)
    nir_array = nir_im.read(4).astype(float)
    nir_edge_s02 = feature.canny(nir_array, sigma=s_val)
    outfile = "nir_canny_" + str(s_val) + ".tif"
    opath = os.path.join(outdir,outfile)
    with rio.open(opath, "w", **kwargs) as oras:
        oras.write_band(1, nir_edge_s02.astype(rio.uint8))
        
#red_image = r"Q:/Arid Riparian Project/Data/test/test_NAIP_sub1.tif"
with rio.open(image) as red_im:
    kwargs = red_im.profile
    kwargs.update(count=1)
    red_array = red_im.read(1).astype(float)
    red_edge_s02 = feature.canny(red_array, sigma=s_val)
    outfile = "red_canny_" + str(s_val) + ".tif"
    opath = os.path.join(outdir, outfile)
    with rio.open(opath, "w", **kwargs) as oras:
        oras.write_band(1, red_edge_s02.astype(rio.uint8))
    
#green_image = r"Q:/Arid Riparian Project/Data/test/test_NAIP_sub2.tif"
with rio.open(image) as green_im:
    kwargs = green_im.profile
    kwargs.update(count=1)
    green_array = green_im.read(2).astype(float)
    green_edge_s02 = feature.canny(green_array, sigma=s_val)
    outfile = "green_canny_" + str(s_val) + ".tif"
    opath = os.path.join(outdir, outfile)
    with rio.open(opath, "w", **kwargs) as oras:
        oras.write_band(1, green_edge_s02.astype(rio.uint8))
    
#blue_image = r"Q:/Arid Riparian Project/Data/test/test_NAIP_sub3.tif"
with rio.open(image) as blue_im:
    kwargs = blue_im.profile
    kwargs.update(count=1)
    blue_array = blue_im.read(3).astype(float)
    blue_edge_s02 = feature.canny(blue_array, sigma=s_val)
    outfile = "blue_canny_" + str(s_val) + ".tif"
    opath = os.path.join(outdir, outfile)
    with rio.open(opath, "w", **kwargs) as oras:
        oras.write_band(1, blue_edge_s02.astype(rio.uint8))
    
ndvi_array = (nir_array-red_array)/(nir_array+red_array)
ndvi_edge_s02 = feature.canny(ndvi_array, sigma=s_val)
outfile = "ndvi_canny_" + str(s_val) + ".tif"
opath = os.path.join(outdir, outfile)
with rio.open(opath, 'w', **kwargs) as oras:
    oras.write_band(1, ndvi_edge_s02.astype(rio.uint8))



#all_ims = (nir_edge_s02 + red_edge_s02 + green_edge_s02 + blue_edge_s02 + nir_edge_s02)
"""

imgplot = plt.imshow(nir_array)
io.show()

#io.imshow(nir_edge)
#io.show()

io.imshow(ndvi_edge_s02)
io.show()

io.imshow(nir_edge_s02)
io.show()

io.imshow(red_edge_s02)
io.show()

io.imshow(green_edge_s02)
io.show()

io.imshow(blue_edge_s02)
io.show()

"""

# %%
from skimage import measure
help(measure.label)

# %%
help(feature.canny)

# %%
import numpy as np
from skimage import data, util, filters, color
from skimage.morphology import watershed
import matplotlib.pyplot as plt

nir_image = r"Q:/Arid Riparian Project/Data/test/test_NAIP_sub4.tif"
with rio.open(nir_image) as nir_im:
    nir_array = nir_im.read(1)

coins = nir_array
edges = filters.sobel(coins)

grid = util.regular_grid(coins.shape, n_points=300)

seeds = np.zeros(coins.shape, dtype=int)
seeds[grid] = np.arange(seeds[grid].size).reshape(seeds[grid].shape) + 1

w0 = watershed(edges, seeds)
w1 = watershed(edges, seeds, compactness=0.05)

fig, (ax0, ax1) = plt.subplots(1, 2)

ax0.imshow(color.label2rgb(w0, coins))
ax0.set_title('Classical watershed')

ax1.imshow(color.label2rgb(w1, coins))
ax1.set_title('Compact watershed')

# %%
from scipy.spatial.distance import cdist

drainage = r"Q:\Arid Riparian Project\Data\test\drainage_network_clip.tif"

Y = cdist(XA, XB, 'euclidean')

# %%
import os
import pandas as pd
import geopandas as gpd
import numpy as np
import gdal, osr
import rasterio as rio
import numpy as np
from datetime import datetime
from sklearn.linear_model import LogisticRegression, BayesianRidge
from sklearn.ensemble import RandomForestRegressor

import Utilities as utilities

# %%
nhd_dir = r"M:\Data\NHD"

watersheds_shp = os.path.join(nhd_dir, "WBDHU4_Arizona.shp")

nhd_rasters_dir = os.path.join(nhd_dir, "Rasters")

rsac_pred_dir = os.path.join(nhd_dir, "RSAC_VB_Preds")
utilities.useDirectory(rsac_pred_dir)

vb_classification_pnts = os.path.join(nhd_dir, "VM_TrainingData_20180608.shp")

overwrite = True

extracts_shp = os.path.join(nhd_dir, "VB_Predictors_Extracts.shp")

# %%
def get_values(geom):

    # print(row)
    # geom = row['geometry']
    x = geom.centroid.x
    y = geom.centroid.y

    values = []
    # for raster in raster_objects:
    # print("Starting Raster Extract for %s at x:%s y:%s" % (os.path.basename(raster), str(x), str(y)))
    # with rio.open(raster) as ras:

    for val in elev_ras.sample([(x, y)]):
        values += np.ndarray.tolist(val)
    for val in float32_ras.sample([(x, y)]):
        values += np.ndarray.tolist(val)

    return pd.Series(values, index=raster_names)


def getRasterNamesList(pdir):
    raster_paths = []
    raster_names = []
    for root, dirs, files in os.walk(pdir):
        for file in files:
            if file.endswith(".tif") or file.endswith(".img"):
                fpath = os.path.join(root, file).replace("\\", "/")
                if "elev_meters" not in file.lower():
                    raster_names.append(file[:-4])
                    raster_paths.append(fpath)
                else:
                    raster_names.insert(0, file[:-4])
                    raster_paths.insert(0, fpath)

    # elev_raster = os.path.join(pdir, "elev_meters.tif").replace("\\", "/")

    # raster_paths = [elev_raster] + float32_raster_paths
    # raster_names = ["elev_meters"] + raster_names

    return [raster_names, raster_paths]


def createClassifiedFile(rasters, regmodel, regname, overwrite=False):
    cl_start = datetime.now()

    output_fname = "VB_" + watershed + "_" + subdir + "_" + regname + ".tif"

    outquad_loc = os.path.join(rsac_pred_dir, watershed)
    if not os.path.exists(outquad_loc):
        os.mkdir(outquad_loc)

    loc_classified_file = os.path.join(outquad_loc, output_fname)

    if not os.path.exists(loc_classified_file) or overwrite:
        # GET RASTER INFO FROM INPUT
        # NEED TO GET BANDS DATA INTO SINGLE ARRAY FOR OUTPUT CLASSIFICATION
        # bands_data_rio = []
        bands_data = []
        for inras in rasters:
            print("Reading in raster file as array - %s" % inras)

            with rio.open(inras) as raster:
                kwargs = raster.profile
                b_array = raster.read(1).astype(rio.float32)

            bands_data.append(b_array)

        # CREATE NP DATASTACK FROM ALL RASTERS
        print("Creating numpy array stack...")
        bands_data = np.dstack(bands_data)

        # print("BANDS_DATA.SHAPE: ", bands_data.shape)
        # CREATE VARIABLES OF ROWS, COLUMNS, AND NUMBER OF BANDS
        rows, cols, n_bands = bands_data.shape
        n_samples = rows * cols
        # print("N_Samples: ", n_samples)
        # print("n_bands: ", n_bands)

        # CREATE EMPTY ARRAY WITH SAME SIZE AS RASTER
        print("Reshaping numpy array to raster shape...")
        flat_pixels = bands_data.reshape((n_samples, n_bands))

        print("Predicting Valley Bottoms...")
        result = regmodel.predict(flat_pixels)

        # Reshape the result: split the labeled pixels into rows to create an image
        classification = result.reshape((rows, cols))

        # WRITE OUT THE CLASSIFIED ARRAY TO RASTER BASED ON PROPERTIES OF TRAINING RASTERS
        # write_geotiff(loc_classified_file, classification, geo_transform, proj, classes, COLORS)

        kwargs.update(
            dtype=rio.float32
        )
        with rio.open(loc_classified_file, 'w', **kwargs) as outras:
            outras.write_band(1, classification.astype(rio.float32))

        print("Classification created:\n\t", output_fname, " in ", str(datetime.now() - cl_start))
    else:
        print("The file exists. Skipping %s" % file)

    return loc_classified_file


def rasterSubDivide(preds_dir, overwrite=False):
    parent_dir = os.path.abspath(os.path.join(preds_dir, os.pardir))
    outdir = os.path.join(parent_dir, "predictors_quads")
    utilities.useDirectory(outdir)

    rasters = getRasterNamesList(preds_dir)[1]

    for raster in rasters:
        reference_f = gdal.Open(raster)
        geo_transform = reference_f.GetGeoTransform()
        resx = geo_transform[1]
        resy = geo_transform[5]
        proj = reference_f.GetProjectionRef()
        minx = geo_transform[0]
        maxy = geo_transform[3]
        maxx = minx + (resx * reference_f.RasterXSize)
        miny = maxy + (resy * reference_f.RasterYSize)
        print("FULL EXTENT: ", minx, miny, maxx, maxy)

        quads_extent_dict = {}

        quad1_minx = str(minx)
        quad1_maxx = str(minx + ((maxx - minx) / 2))
        quad1_miny = str(miny + ((maxy - miny) / 2))
        quad1_maxy = str(maxy)
        quads_extent_dict[1] = " ".join([quad1_minx, quad1_miny, quad1_maxx, quad1_maxy])

        quad2_minx = str(quad1_maxx)
        quad2_maxx = str(maxx)
        quad2_miny = str(quad1_miny)
        quad2_maxy = str(maxy)

        quads_extent_dict[2] = " ".join([quad2_minx, quad2_miny, quad2_maxx, quad2_maxy])

        quad3_minx = str(minx)
        quad3_maxx = str(quad1_maxx)
        quad3_miny = str(miny)
        quad3_maxy = str(quad1_miny)

        quads_extent_dict[3] = " ".join([quad3_minx, quad3_miny, quad3_maxx, quad3_maxy])

        quad4_minx = str(quad1_maxx)
        quad4_maxx = str(maxx)
        quad4_miny = str(miny)
        quad4_maxy = str(quad1_miny)

        quads_extent_dict[4] = " ".join([quad4_minx, quad4_miny, quad4_maxx, quad4_maxy])

        print("Clipping Quads for %s" % raster)
        for i in range(1, 5):
            print("Starting on quad %d" % i)
            quad_name = "quad" + str(i)
            quad_dir = os.path.join(outdir, quad_name)
            utilities.useDirectory(quad_dir)

            oname = os.path.splitext(os.path.basename(raster))[0] + "_" + quad_name + ".tif"
            opath = os.path.join(quad_dir, oname)

            if not os.path.exists(opath) or overwrite:
                ouput_options = "-overwrite -t_srs %s -tr %s %s -te_srs %s -te %s" % (
                    proj, resx, resy, proj, quads_extent_dict[i])

                print("Executing gdal_warp operation on %s with extent %s" % (raster, quads_extent_dict[i]))
                gdal.Warp(opath, raster, options=ouput_options)

    return outdir

# %%
if not os.path.exists(extracts_shp) or overwrite:
    watersheds_df = gpd.read_file(watersheds_shp)
    class_points_df = gpd.read_file(vb_classification_pnts)

    if not watersheds_df.crs == class_points_df.crs:
        class_points_df.to_crs(watersheds_df.crs, inplace=True)

    vbpoints_ras_extract = gpd.sjoin(class_points_df, watersheds_df, op='within')
    print(vbpoints_ras_extract.head())

    with rio.open(r"M:\Data\NHD\Rasters\HRNHDPlusRasters1505\fac.tif") as ras:
        raster_crs = ras.crs

    from rasterio import crs
    raster_crs = "+proj=aea +lat_1=29.5 +lat_2=45.5 +lat_0=37.5 +lon_0=-96 +x_0=0 +y_0=0 +ellps=GRS80 +datum=NAD83 +units=m +no_defs "

    vbpoints_ras_extract.to_crs(raster_crs, inplace=True)
    print(vbpoints_ras_extract.geometry.head())

    for watershed, group in vbpoints_ras_extract.groupby("HUC4"):
        print("Starting extraction on points in watershed %s" % watershed)

        if watershed == "1507":
            temp = vbpoints_ras_extract.loc[vbpoints_ras_extract.HUC4 == watershed]
            print(temp.shape)


        # FIND RELEVANT WATERSHED DIRECTORY
        for dir in os.listdir(nhd_rasters_dir):
            if watershed in dir:
                w_dir = os.path.join(nhd_rasters_dir, dir)
                break

        predictors_dir = os.path.join(w_dir, "Predictors")

        float32_raster_paths = []
        raster_names = []
        for root, dirs, files in os.walk(predictors_dir):
            for file in files:
                if file.endswith(".tif") or file.endswith(".img"):
                    if file.lower() != "elev_meters.tif":
                        raster_names.append(file[:-4])
                        float32_raster_paths.append(os.path.join(root, file).replace("\\", "/"))

        elev_raster = os.path.join(predictors_dir, "elev_meters.tif").replace("\\", "/")

        vrt_of_rasters = os.path.join(predictors_dir, "float32_predictors.vrt")

        if not os.path.exists(vrt_of_rasters):
            print("Building VRT of FLOAT32 Rasters...")
            build_vrt = "gdalbuildvrt -overwrite -separate %s %s" % (vrt_of_rasters, " ".join(float32_raster_paths))
            os.system(build_vrt)

        if not os.path.exists(os.path.join(predictors_dir, "elev_meters.tif")):
            print("PROBLEM - %s doesn't exist in directory %s" % ("elev_meters.tif", predictors_dir))
            raise Exception

        rasters = [elev_raster] + float32_raster_paths
        raster_names = ["elev_meters"] + raster_names
        print("Raster Names: ", raster_names)

        if "elev_meters" not in vbpoints_ras_extract:
            for name in raster_names:
                #print(name)
                vbpoints_ras_extract[name] = np.NaN

        with rio.open(elev_raster) as elev_ras:
            with rio.open(vrt_of_rasters) as float32_ras:
                vbpoints_ras_extract.loc[vbpoints_ras_extract.HUC4 == watershed, raster_names] = \
                    vbpoints_ras_extract.loc[vbpoints_ras_extract.HUC4 == watershed, "geometry"].apply(get_values)

    print("273")
    print("Finished value extracts. Saving to file: %s" % extracts_shp)
    vbpoints_ras_extract.to_file(driver="ESRI Shapefile", filename=extracts_shp)
else:
    vbpoints_ras_extract = gpd.read_file(extracts_shp)

# %%
raster_names = vbpoints_ras_extract.columns.tolist()[18:-1]
print("RASTER NAMES: %s" % raster_names)

# TRAIN RANDOM FORESTS
print("Beginning Regression Training")
n_job = 2
maxiter = 100
solv = 'liblinear'

# http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html#sklearn.linear_model.LogisticRegression
regressorname = "RandomForestsReg"
if regressorname == "LogisticReg":
    regressor = LogisticRegression(C=1.0, solver=solv, max_iter=maxiter, verbose=1, n_jobs=n_job)
elif regressorname == "BaysianReg":
    regressor = BayesianRidge(verbose=True)
elif regressorname == "RandomForestsReg":
    # http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html#sklearn.ensemble.RandomForestRegressor
    regressor = RandomForestRegressor(n_jobs=n_job, verbose=True, min_samples_leaf=20)

regressor.fit(vbpoints_ras_extract[raster_names].dropna(),
              vbpoints_ras_extract[raster_names+["VB"]].dropna()["VB"])


# CREATE CLASSIFIED RASTERS FOR QUARTER QUADS USED IN TRAINING DATA FIRST
for watershed, group in vbpoints_ras_extract.groupby("HUC4"):
    # FIND RELEVANT WATERSHED DIRECTORY
    for dir in os.listdir(nhd_rasters_dir):
        if watershed in dir:
            w_dir = os.path.join(nhd_rasters_dir, dir)

    predictors_dir = os.path.join(w_dir, "Predictors")

    if watershed == "1505":
        quads_dir = rasterSubDivide(predictors_dir, overwrite=True)
        print(quads_dir)
        for subdir in os.listdir(quads_dir):
            #print(subdir)
            dirpath = os.path.join(quads_dir, subdir)
            rasters = getRasterNamesList(dirpath)[1]
            #print("Starting on directory : %s" % dirpath)
            classified_File = createClassifiedFile(rasters, regressor, regressorname, overwrite=True)

# %% [markdown]
# ## Quickshift segmentation
# Extraction of river from naip image
# from: https://gis.stackexchange.com/a/152932

# %%
from __future__ import print_function

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from skimage import io
from skimage.segmentation import quickshift
import rasterio as rio
import os
from datetime import datetime

# The input 4-band NAIP image
#river = r'C:\path\to\naip_image.tif'
#bens_test_image = r"Q:/Arid Riparian Project/Data/test/test_NAIP_sub1.tif"
#bens_test_image = os.path.abspath(r"Q:/AARMP_TestBed/NAIP/m_3211042_nw_12_1_20150530-2.tif")
#bens_test_image = os.path.abspath(r"Q:/Arid Riparian Project/Data/test/test_NAIP_sub.tif")


# Convert image to numpy array
img = io.imread(bens_test_image)
plt.imshow(img)

# %%
start = datetime.now()
# Run the quick shift segmentation
segments = quickshift(img,
                      kernel_size=1, 
                      convert2lab=False,
                      max_dist=3,
                      ratio=0.1)

print("Quickshift number of segments: %d" % len(np.unique(segments)))
end = datetime.now()
print("Elapsed: ", end-start)

# View the segments via Python
#plt.imshow(segments)

#segments.shape

with rio.open(bens_test_image) as ras:
    prof = ras.profile
    mx = prof['transform'][0] #myRaster.extent.XMin
    my = prof['transform'][3] - prof['height'] #myRaster.extent.YMin
    sr = ras.crs #myRaster.spatialReference
    
    red_array = ras.read(1).astype(rio.float32)
    nir_array = ras.read(4).astype(rio.float32)
    
    ndvi = (nir_array-red_array) / (nir_array+red_array)

prof.update(
    count=1,
    dtype=rio.int16
)

with rio.open(r"Q:/Arid Riparian Project/Data/test/segments.tif", 'w', **prof) as outras:
    outras.write_band(1, segments.astype(rio.int16))

prof.update(
    dtype=rio.float32
)
with rio.open(r"Q:/Arid Riparian Project/Data/test/test_NAIP_sub_NDVI.tif", 'w', **prof) as outras:
    outras.write_band(1, ndvi.astype(rio.float32))

# %%
bens_test_image = os.path.abspath(r"Q:/Arid Riparian Project/Data/test/test_NAIP_sub_NDVI.tif")

# Convert image to numpy array
img = io.imread(bens_test_image)
plt.imshow(img)

# %% [markdown]
# # FELZENSWALB

# %%
from __future__ import print_function

# %matplotlib inline

import os
import rasterio as rio
import numpy as np
import matplotlib.pyplot as plt
from skimage import io
from skimage.segmentation import quickshift

from datetime import datetime
from skimage.segmentation import felzenszwalb
from scipy import ndimage

in_naip = os.path.abspath(r"Q:/Arid Riparian Project/Data/test/test_NAIP_sub.tif")
#in_naip = os.path.abspath(r"Q:/Arid Riparian Project/Data/test/test_NAIP_sub_NDVI.tif")
in_naip = r"Q:/AARMP_TestBed/NAIP/m_3211042_nw_12_1_20150530.tif"

# %%
with rio.open(in_naip) as ras:
    in_naip_array_1 = ras.read(1)
    in_naip_array_2 = ras.read(2)
    in_naip_array_3 = ras.read(3)
    in_naip_array_4 = ras.read(4)

# %%
def segmentImage(image_array, seg_type="felzenswalb"):
    print("Beginning image segmentation on array")
    seg_start = datetime.now()
    if seg_type == "felzenswalb":
        segments_fz = felzenszwalb(image_array, scale=25, sigma=0.5, min_size=3)
    else:
        print("Unknown segmentation algorithm. Exiting...")
        raise ValueError

    seg_end = datetime.now()
    print(
        "Felzenszwalb number of segments: {}. \n\t{} elapsed.".format(len(np.unique(segments_fz)), seg_end - seg_start))

    return segments_fz

def calculateZonalStats(zones, in_image, type="mean"):
    label_im = label(in_image, connectivity=2) + 1 # add one to all values in array because mean calculation ignores labels with 0 value
    nb_labels = len(np.unique(label_im))
    mean_vals = ndimage.mean(in_image, label_im, range(1, nb_labels + 1)) # calculate mean value for image at each label number
    
    rows, cols = in_image.shape
    
    # iterate through array of labels and assign the array the value of the label at the location of the label value in the mean array
    # somehow, this is the fastest way i can find to do this at 5 minutes per raster
    #start = datetime.now()
    flat_labels = flattenArray(label_im)
    for i in range(0,len(flat_labels)-1):
        val = flat_labels[[i]]
        flat_labels[[i]] = mean_vals[[val-1]]

    #print(flat_labels)
    #print(datetime.now()-start)
    new_naip = flat_labels.reshape((rows, cols))
    
    """
    mean_start = datetime.now()
    image = np.copy(in_image)
    for count, val in enumerate(np.unique(zones)):
        if count % 1000 == 0:
            print("\t", count)
        subarray = zones == val
        if type == "mean":
            image[subarray] = np.mean(image[subarray])
        else:
            print("Unknown statistical type")
            raise ValueError

    mean_end = datetime.now()
    print("Finished zonal mean calculation in {}".format(mean_end - mean_start))
    """
    return new_naip

# %%
in_naip_1_seg = segmentImage(in_naip_array_1)
# Out:
# Beginning image segmentation on array
# Felzenszwalb number of segments: 2270074.
# 	0:03:18.010709 elapsed.

# %%
#min_row; max_row and ``[min_col; max_col)
sub = a[0:2,0:3]
sub[sub==1] = 0
a[0:2,0:3] = sub

# %%
a = np.copy(label_im)
a
# Out:
# array([[      1,       1,       1, ...,    1576,    1577,    1577],
#        [      1,       1,       2, ...,    1576,    1577,    1577],
#        [   1789,    1789,    1789, ...,    1576,    1577,    1577],
#        ...,
#        [2264926, 2264926, 2269533, ..., 2269258, 2269258, 2269258],
#        [2269533, 2269533, 2269533, ..., 2269258, 2269258, 2269258],
#        [2269533, 2269533, 2269533, ..., 2269994, 2269258, 2269258]], dtype=int64)

# %%
label_im = label(in_naip_1_seg, connectivity=2) + 1
regions = measure.regionprops(label_im, intensity_image=in_naip_array_1)

out_array = np.copy(label_im)

for r in regions:
    val = r.label
    if val < 1000000:
        bbox = r.bbox
        min_row, max_row, min_col, max_col = bbox

        sub_array = label_im[min_row:min_col, max_row:max_col]
        sub_array[sub_array==val] = r.mean_intensity
        #print(sub_array)
        out_array[min_row:min_col, max_row:max_col] = sub_array

# %%
with rio.open(in_naip) as ras:
    prof = ras.profile

prof.update(count=1)
with rio.open(r"Q:/AARMP_TestBed/NAIP/m_3211042_nw_12_1_20150530_band1_fz.tif", 'w', **prof) as outras:
    outras.write_band(1, out_array.astype(rio.uint8))
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\rasterio\__init__.py:160: FutureWarning: GDAL-style transforms are deprecated and will not be supported in Rasterio 1.0.
#   transform = guard_transform(transform)

# %%
prof.update(dtype=rio.uint32)

with rio.open(r"Q:/AARMP_TestBed/NAIP/m_3211042_nw_12_1_20150530_band1_fz_segs.tif", 'w', **prof) as outras:
    outras.write_band(1, in_naip_1_seg.astype(rio.uint32))
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\rasterio\__init__.py:160: FutureWarning: GDAL-style transforms are deprecated and will not be supported in Rasterio 1.0.
#   transform = guard_transform(transform)

# %%
import timeit

def means_for(zones, image):
    #print(image)
    for count, val in enumerate(np.unique(zones)):
        if count % 1000 == 0:
            print(count)
        subarray = zones == val
        image[subarray] = np.mean(image[subarray])
    #subarray = zones == val
    #image[subarray] = np.mean(image[subarray])
    #np.vectorize(lambda val: np.mean(image[zones==val]), np.unique(zones))#, otypes=[float])(zones)
    
    ##my_list = [1, 5, 4, 6, 8, 11, 3, 12]

    ##new_list = list(map(lambda x: x * 2 , my_list))
    #image = map(lambda val: np.mean(image[zones==val]), np.unique(zones))
    ## Output: [2, 10, 8, 12, 16, 22, 6, 24]
    #print(image)
    return image

def means_map(zones, image):
    #print(image)
    #for count, val in enumerate(np.unique(zones)):
    #    subarray = zones == val
    #    image[subarray] = np.mean(image[subarray])
    #subarray = zones == val
    #image[subarray] = np.mean(image[subarray])
    #np.vectorize(lambda val: np.mean(image[zones==val]), np.unique(zones))#, otypes=[float])(zones)
    
    ##my_list = [1, 5, 4, 6, 8, 11, 3, 12]
    #meaner = lambda v: np.mean(image[zones==v])
    #def meaner(val):
    meaner = lambda v: np.where(zones == v, image[zones == v].mean(), image)
    
    meaner = lambda v: np.where(zones == v, image[zones == v].mean(), image)
                        
    ##new_list = list(map(lambda x: x * 2 , my_list))
    #image = np.array(map(meaner, np.unique(zones)))
    image = np.array([meaner(n) for n in np.unique(zones)])
    #print(image)
    ## Output: [2, 10, 8, 12, 16, 22, 6, 24]

    return image

def calculateZonalStats(zones, in_image):
    label_im = label(in_image, connectivity=2) # add one to all values in array because mean calculation ignores labels with 0 value
    nb_labels = len(np.unique(label_im))
    mean_vals = ndimage.mean(in_image, label_im, range(1, nb_labels + 1)) # calculate mean value for image at each label number
    print("num mean vals:", len(mean_vals))
    rows, cols = in_image.shape
    
    # iterate through array of labels and assign the array the value of the label at the location of the label value in the mean array
    # somehow, this is the fastest way i can find to do this at 5 minutes per raster
    #start = datetime.now()
    flat_labels = flattenArray(label_im)
    print(flat_labels)
    print("length label im: ", np.unique(flat_labels))
    for i in range(0,len(flat_labels)):
        val = flat_labels[[i]]
        val2 = val - 1
        if val2 == 8655:
            print(val)
            print("index retrieval: ", val2)
            flat_labels[[i]] = mean_vals[[8654]]
        else:
            flat_labels[[i]] = mean_vals[[val2]]

    #print(flat_labels)
    #print(datetime.now()-start)
    new_naip = flat_labels.reshape((rows, cols))
    return new_naip
 
band1 = flattenArray(in_naip_array_1)
segs = flattenArray(in_naip_1_seg)
#print("image in: ")
#print(in_naip_array_1)
#%timeit means_for(in_naip_1_seg, in_naip_array_1)
#%timeit means_map(in_naip_1_seg, in_naip_array_1)

#%timeit calculateZonalStats(in_naip_1_seg, in_naip_array_1)

# %%
 # add one to all values in array because mean calculation ignores labels with 0 value
#nb_labels = len(np.unique(label_im))
#mean_vals = ndimage.mean(in_naip_array_1, label_im, range(1, nb_labels + 1))

# %%
def lammean():
    image = in_naip_array_1
    meaner = lambda v: np.mean(in_naip_array_1[in_naip_1_seg==v])

    for i in np.unique(in_naip_1_seg):
        image[in_naip_1_seg == i] = meaner(i)
    
    return image

# %timeit img = lammean()
# Out:
# 1 loop, best of 3: 2.23 s per loop

# %%
print(img)
# Out:
# [[ 85  85  85 ..., 144 173 173]
#  [ 85  85  85 ..., 144 173 173]
#  [ 85  85  85 ..., 144 144 144]
#  ...,
#  [ 63  63  63 ..., 203 203 203]
#  [ 78  78  73 ..., 203 203 203]
#  [ 78  78  73 ..., 203 203 203]]

# %%
from skimage import measure
from skimage.measure import label

img = label(in_naip_1_seg, connectivity=1) +1
print(in_naip_1_seg)
print(img)
regions = measure.regionprops(img, intensity_image=in_naip_array_1)
#print([r.mean_intensity for r in regions])
#print([r.label for r in regions])
#print(len(regions))
#help(measure.regionprops)
#img = np.copy(in_naip_1_seg)
def meanit(regions, image):
    for r in regions:
        #print(r.label, r.mean_intensity)
        image[image==r.label] = r.mean_intensity
        
    return image

#%timeit meanit()
img.shape
# Out:
# [[   0    0    0 ...,  118  119  119]
#  [   0    0    0 ...,  118  119  119]
#  [   0    0    0 ...,  118  118  118]
#  ...,
#  [8442 8442 8442 ..., 8740 8740 8740]
#  [8844 8844 8709 ..., 8740 8740 8740]
#  [8844 8844 8709 ..., 8740 8740 8740]]
# [[    1     1     1 ...,   126   127   127]
#  [    1     1     1 ...,   126   127   127]
#  [    1     1     1 ...,   126   126   126]
#  ...,
#  [17785 17785 17785 ..., 18432 18432 18432]
#  [18653 18653 18355 ..., 18432 18432 18432]
#  [18653 18653 18355 ..., 18432 18432 18432]]
# (403, 496)

# %%
segments_1_mean = calculateZonalStats(in_naip_1_seg, in_naip_array_1)
# Out:
# 	 0
# 	 1000
# 	 2000
# 	 3000
# 	 4000
# 	 5000
# 	 6000
# 	 7000
# 	 8000
# Finished zonal mean calculation in 0:00:01.468891

# %%
segments_1_mean
# Out:
# array([[ 85,  85,  85, ..., 144, 173, 173],
#        [ 85,  85,  85, ..., 144, 173, 173],
#        [ 85,  85,  85, ..., 144, 144, 144],
#        ...,
#        [ 63,  63,  63, ..., 203, 203, 203],
#        [ 78,  78,  73, ..., 203, 203, 203],
#        [ 78,  78,  73, ..., 203, 203, 203]], dtype=uint8)

# %%
in_naip_2_seg = segmentImage(in_naip_array_2)
segments_2_mean = calculateZonalStats(in_naip_2_seg, in_naip_array_2)

segments_3_mean = calculateZonalStats(in_naip_3_seg, in_naip_array_3)
in_naip_3_seg = segmentImage(in_naip_array_3)

in_naip_4_seg = segmentImage(in_naip_array_4)
segments_4_mean = calculateZonalStats(in_naip_4_seg, in_naip_array_4)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-59043b0658e6> in <module>()
# ----> 1 segments_1_mean = calculateZonalStats(in_naip_1_seg, in_naip_array_1)
#
# <ipython-input-8-0714c7769fae> in calculateZonalStats(zones, in_image, type)
#       2     image = np.copy(in_image)
#       3     for val in np.unique(zones):
# ----> 4         subarray = zones == val
#       5         if type == "mean":
#       6             image[subarray] = np.mean(image[subarray])
#
# KeyboardInterrupt:

# %%
with rio.open(in_naip) as ras:
    prof = ras.profile

prof.update(count=1)
with rio.open(r"Q:/AARMP_TestBed/NAIP/m_3211042_nw_12_1_20150530_band1_fz.tif", 'w', **prof) as outras:
    outras.write_band(1, flat_labels.astype(rio.uint8))
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\rasterio\__init__.py:160: FutureWarning: GDAL-style transforms are deprecated and will not be supported in Rasterio 1.0.
#   transform = guard_transform(transform)

# %%
bands = [segments_1_mean, segments_2_mean, segments_3_mean, segments_4_mean]

with rio.open(in_naip) as ras:
    prof = ras.profile

prof.update(
    count=4,
    dtype=rio.uint8
)

#with rio.open(r"Q:/Arid Riparian Project/Data/test/segments_fz.tif", 'w', **prof) as outras:
#    outras.write_band(1, segments_fz.astype(rio.int16))
#plt.imshow(segments_fz)


#prof.update(dtype=rio.float32)
with rio.open(r"Q:/AARMP_TestBed/NAIP/m_3211042_nw_12_1_20150530_fz.tif", 'w', **prof) as outras:
    for id, layer in enumerate(bands):
            outras.write_band(id + 1, layer)

# %% [markdown]
# ------------------------------------

# %%
start = datetime.now()
# Run the quick shift segmentationdata:image/png;base64,...
segments = quickshift(img,
                      kernel_size=1, 
                      convert2lab=False,
                      max_dist=3,
                      ratio=0.9)

print("Quickshift number of segments: %d" % len(np.unique(segments)))
end = datetime.now()
print("Elapsed: ", end-start)

# View the segments via Python
#plt.imshow(segments)

#segments.shape

with rio.open(bens_test_image) as ras:
    prof = ras.profile
    #mx = prof['transform'][0] #myRaster.extent.XMin
    #my = prof['transform'][3] - prof['height'] #myRaster.extent.YMin
    #sr = ras.crs #myRaster.spatialReference

prof.update(
    count=1,
    dtype=rio.int16
)

with rio.open(r"Q:/Arid Riparian Project/Data/test/segments.tif", 'w', **prof) as outras:
    outras.write_band(1, segments.astype(rio.int16))

prof.update(
    dtype=rio.float32
)
with rio.open(r"Q:/Arid Riparian Project/Data/test/test_sub_NDVI.tif", 'w', **prof) as outras:
    outras.write_band(1, ndvi.astype(rio.float32))

# %%
# Get raster metrics for coordinate info
myRaster = arcpy.sa.Raster(river)

# Lower left coordinate of block (in map units)
mx = myRaster.extent.XMin
my = myRaster.extent.YMin
sr = myRaster.spatialReference

# Note the use of arcpy to convert numpy array to raster
seg = arcpy.NumPyArrayToRaster(segments, arcpy.Point(mx, my),
                               myRaster.meanCellWidth,
                               myRaster.meanCellHeight)

outRaster = r'C:\path\to\segments.tif'
seg_temp = seg.save(outRaster)
arcpy.DefineProjection_management(outRaster, sr)

# Calculate NDVI from bands 4 and 3
b4 = arcpy.sa.Raster(r'C:\path\to\naip_image.tif\Band_4')
b3 = arcpy.sa.Raster(r'C:\path\to\naip_image.tif\Band_3')
ndvi = arcpy.sa.Float(b4-b3) / arcpy.sa.Float(b4+b3)

# Extract NDVI values based on image object boundaries
zones = arcpy.sa.ZonalStatistics(outRaster, "VALUE", ndvi, "MEAN")
zones.save(r'C:\path\to\zones.tif')

# Classify the segments based on NDVI values
binary = arcpy.sa.Con(zones < 20, 1, 0)
binary.save(r'C:\path\to\classified_image_objects.tif')
